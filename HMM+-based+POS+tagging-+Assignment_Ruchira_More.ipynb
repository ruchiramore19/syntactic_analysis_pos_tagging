# %% [markdown]
# ## POS tagging using modified Viterbi

# %% [markdown]
# ## 1. Data Preparation

# %%
# Importing libraries

import nltk
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize
import random
import numpy as np
import pandas as pd
import pprint, time
import random
import collections
import time
nltk.download('universal_tagset')
nltk.download('treebank')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\DELL\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# reading the Treebank tagged sentences

nltk_data = list(nltk.corpus.treebank.tagged_sents(tagset='universal'))

# %%
# Train Test Split
train_set, test_set = train_test_split(nltk_data,test_size=0.05, random_state=100)

print(len(train_set))
print(len(test_set))
# Out:
# 3718
# 196

# %%
# Extract words with tags from all sentences
train_tagged_words = [tup for sentence in train_set for tup in sentence]

# %%
# List out all unique words
unique_words = set([tup[0] for tup in train_tagged_words])

# %%
#List out all unique tags
unique_tags = set([tup[1] for tup in train_tagged_words])
#len(T)

# %% [markdown]
# ## 2. HMM

# %%
# compute word given tag: Emission Probability

def word_given_tag(word, tag, train_bag = train_tagged_words):
    tag_list = [pair for pair in train_bag if pair[1]==tag]
    count_tag = len(tag_list)
    w_given_tag_list = [pair[0] for pair in tag_list if pair[0]==word]
    count_w_given_tag = len(w_given_tag_list)
    
    return (count_w_given_tag, count_tag)

# %%
# compute tag given tag: tag2(t2) given tag1 (t1), i.e. Transition Probability

def t2_given_t1(t2, t1, train_bag = train_tagged_words):
    tags = [pair[1] for pair in train_bag]
    count_t1 = len([t for t in tags if t==t1])
    count_t2_t1 = 0
    for index in range(len(tags)-1):
        if tags[index]==t1 and tags[index+1] == t2:
             count_t2_t1 += 1
    return (count_t2_t1, count_t1)

# %%
# creating t x t transition matrix of tags
# each column is t2, each row is t1
# thus M(i, j) represents P(tj given ti)

tags_matrix = np.zeros((len(unique_tags), len(unique_tags)), dtype='float32')
for i, t1 in enumerate(list(unique_tags)):
    for j, t2 in enumerate(list(unique_tags)): 
        tags_matrix[i, j] = t2_given_t1(t2, t1)[0]/t2_given_t1(t2, t1)[1]

# %%
tags_df = pd.DataFrame(tags_matrix, columns = list(unique_tags), index=list(unique_tags))
tags_df
# Out:
#            NUM       PRT         .       ADP      VERB      CONJ       DET  \
# NUM   0.184195  0.026144  0.118835  0.035056  0.016934  0.013072  0.003862
# PRT   0.056102  0.001969  0.043635  0.019357  0.405184  0.002297  0.101050
# .     0.081353  0.002511  0.092923  0.092206  0.088708  0.058032  0.173558
# ADP   0.061910  0.001484  0.039754  0.017492  0.008481  0.000848  0.323969
# VERB  0.022448  0.031427  0.034291  0.091184  0.168744  0.005186  0.133292
# CONJ  0.042188  0.003709  0.035698  0.053778  0.155308  0.000464  0.118683
# DET   0.021640  0.000240  0.017913  0.009618  0.040394  0.000481  0.005771
# X     0.002857  0.184891  0.162831  0.144898  0.204571  0.010316  0.055229
# ADJ   0.020803  0.010156  0.063882  0.078624  0.011794  0.016052  0.004914
# NOUN  0.009550  0.043357  0.239951  0.177058  0.146955  0.042921  0.013363
# PRON  0.007280  0.012261  0.040613  0.023372  0.484291  0.004981  0.009195
# ADV   0.031624  0.014314  0.135153  0.119507  0.344541  0.006991  0.069907
#
#              X       ADJ      NOUN      PRON       ADV
# NUM   0.211824  0.033571  0.352347  0.001485  0.002674
# PRT   0.013123  0.083661  0.245735  0.017717  0.010171
# .     0.026908  0.043681  0.222531  0.065208  0.052292
# ADP   0.034984  0.107389  0.321213  0.069119  0.013357
# VERB  0.218438  0.065640  0.111386  0.035916  0.082050
# CONJ  0.008809  0.118683  0.350487  0.058414  0.053778
# DET   0.045323  0.204977  0.637293  0.003727  0.012623
# X     0.074433  0.016505  0.062371  0.055705  0.025393
# ADJ   0.020311  0.067158  0.700901  0.000491  0.004914
# NOUN  0.028868  0.012165  0.264280  0.004721  0.016813
# PRON  0.092720  0.072031  0.211494  0.007663  0.034100
# ADV   0.023302  0.130160  0.031624  0.015646  0.077230

# %% [markdown]
# ## 3.  Build the vanilla Viterbi based POS tagger

# %%
# Viterbi Heuristic
def Viterbi(words, train_bag = train_tagged_words):
    state = []    
    unique_tags_list = list(unique_tags)
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in unique_tags:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]  
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        pmax = max(p)
        # getting state for which probability is maximum
        state_max = unique_tags_list[p.index(pmax)] 
        state.append(state_max)
    return list(zip(words, state))

# %%
# list of untagged words in test set 
test_tagged_words = [tup[0] for sent in test_set for tup in sent]

# %%
#Executing Viterbi algorithm on test data
tagged_seq = Viterbi(test_tagged_words)

# %%
#Accuracy check for tags
test_run_base = [tup for sent in test_set for tup in sent]
correctly_tagged = [i for i, j in zip(tagged_seq, test_run_base) if i == j] 

accuracy = len(correctly_tagged)/len(tagged_seq)
print("Vanilla Viterbi Accuracy ----> ",accuracy)
# Out:
# Vanilla Viterbi Accuracy ---->  0.91030251745293

# %%
#List of incorrectly tagged words
incorrect_tagged_cases = [j for i, j in enumerate(zip(tagged_seq, test_run_base)) if j[0]!=j[1]]
incorrect_tagged_cases
# Out:
# [(('book', 'NOUN'), ('book', 'VERB')),
#  (('stocks', 'NOUN'), ('stocks', 'ADV')),
#  (('up', 'PRT'), ('up', 'ADP')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('ignored', 'NUM'), ('ignored', 'VERB')),
#  (('mine', 'NOUN'), ('mine', 'ADJ')),
#  (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN')),
#  (('first', 'ADJ'), ('first', 'ADV')),
#  (('Preston', 'NUM'), ('Preston', 'NOUN')),
#  (('Birmingham', 'NUM'), ('Birmingham', 'NOUN')),
#  (('Ala', 'NUM'), ('Ala', 'NOUN')),
#  (('clamped', 'NUM'), ('clamped', 'VERB')),
#  (('ankle', 'NUM'), ('ankle', 'NOUN')),
#  (('third-largest', 'NUM'), ('third-largest', 'ADJ')),
#  (('fifth-largest', 'NUM'), ('fifth-largest', 'ADJ')),
#  (('Z.', 'NUM'), ('Z.', 'NOUN')),
#  (('Wick', 'NUM'), ('Wick', 'NOUN')),
#  (('argues', 'NUM'), ('argues', 'VERB')),
#  (('Sit', 'NUM'), ('Sit', 'VERB')),
#  (('down', 'PRT'), ('down', 'ADV')),
#  (('British', 'ADJ'), ('British', 'NOUN')),
#  (('halt', 'NOUN'), ('halt', 'VERB')),
#  (('slides', 'NOUN'), ('slides', 'VERB')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('athletic', 'NUM'), ('athletic', 'ADJ')),
#  (('to', 'PRT'), ('to', 'ADJ')),
#  (('better', 'ADJ'), ('better', 'ADV')),
#  (('illustrates', 'NUM'), ('illustrates', 'VERB')),
#  (('attempt', 'VERB'), ('attempt', 'NOUN')),
#  (('usurp', 'NUM'), ('usurp', 'VERB')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('executive-office', 'NUM'), ('executive-office', 'NOUN')),
#  (('administer', 'NUM'), ('administer', 'VERB')),
#  (('disapproved', 'NUM'), ('disapproved', 'VERB')),
#  (('*-58', 'NUM'), ('*-58', 'X')),
#  (('disapproval', 'NUM'), ('disapproval', 'NOUN')),
#  (('accordance', 'NUM'), ('accordance', 'NOUN')),
#  (('applicable', 'NUM'), ('applicable', 'ADJ')),
#  (('Mead', 'NUM'), ('Mead', 'NOUN')),
#  (('Paper', 'NUM'), ('Paper', 'NOUN')),
#  (('Paper', 'NUM'), ('Paper', 'NOUN')),
#  (('Paper', 'NUM'), ('Paper', 'NOUN')),
#  (('Louisiana-Pacific', 'NUM'), ('Louisiana-Pacific', 'NOUN')),
#  (('DeFazio', 'NUM'), ('DeFazio', 'NOUN')),
#  (('criteria', 'NUM'), ('criteria', 'NOUN')),
#  (('Proper', 'NUM'), ('Proper', 'ADJ')),
#  (('English', 'NOUN'), ('English', 'ADJ')),
#  (('rounds', 'NUM'), ('rounds', 'NOUN')),
#  (('highest-pitched', 'NUM'), ('highest-pitched', 'ADJ')),
#  (('descending', 'NUM'), ('descending', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('62-year-old', 'NUM'), ('62-year-old', 'ADJ')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('forest-product', 'NUM'), ('forest-product', 'NOUN')),
#  (('unsolicited', 'NUM'), ('unsolicited', 'ADJ')),
#  (('bid', 'VERB'), ('bid', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('diversified', 'ADJ'), ('diversified', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('impressive', 'NUM'), ('impressive', 'ADJ')),
#  (('issue', 'NOUN'), ('issue', 'VERB')),
#  (('29year', 'NUM'), ('29year', 'ADJ')),
#  (('nine-month', 'NUM'), ('nine-month', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('ECONOMIC', 'NUM'), ('ECONOMIC', 'ADJ')),
#  (('GROWTH', 'NUM'), ('GROWTH', 'NOUN')),
#  (('APPEARS', 'NUM'), ('APPEARS', 'VERB')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('S.A', 'NUM'), ('S.A', 'NOUN')),
#  (('U.S.-Japanese', 'NUM'), ('U.S.-Japanese', 'ADJ')),
#  (('behemoth', 'NUM'), ('behemoth', 'NOUN')),
#  (('*T*-174', 'NUM'), ('*T*-174', 'X')),
#  (('hotels', 'NUM'), ('hotels', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-175', 'NUM'), ('*T*-175', 'X')),
#  (('masters', 'NUM'), ('masters', 'NOUN')),
#  (('Tiny', 'NUM'), ('Tiny', 'NOUN')),
#  (('Tots', 'NUM'), ('Tots', 'NOUN')),
#  (('up', 'ADV'), ('up', 'ADP')),
#  (('past', 'ADJ'), ('past', 'NOUN')),
#  (('Kelli', 'NUM'), ('Kelli', 'NOUN')),
#  (('Green', 'NUM'), ('Green', 'NOUN')),
#  (('senior', 'ADJ'), ('senior', 'NOUN')),
#  (('speculate', 'NUM'), ('speculate', 'VERB')),
#  (('yen-support', 'NUM'), ('yen-support', 'ADJ')),
#  (('intervention', 'NUM'), ('intervention', 'NOUN')),
#  (('excess', 'ADJ'), ('excess', 'NOUN')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('smiles', 'NUM'), ('smiles', 'NOUN')),
#  (('Mont', 'NUM'), ('Mont', 'NOUN')),
#  (('exits', 'NUM'), ('exits', 'NOUN')),
#  (('rebound', 'VERB'), ('rebound', 'NOUN')),
#  (('pushes', 'NUM'), ('pushes', 'VERB')),
#  (('Left', 'NUM'), ('Left', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('so', 'ADP'), ('so', 'ADV')),
#  (('much', 'ADJ'), ('much', 'ADV')),
#  (('Sandoz', 'NUM'), ('Sandoz', 'NOUN')),
#  (('preclinical', 'NUM'), ('preclinical', 'ADJ')),
#  (('vague', 'NUM'), ('vague', 'ADJ')),
#  (('mushy', 'NUM'), ('mushy', 'ADJ')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('viewpoints', 'NUM'), ('viewpoints', 'NOUN')),
#  (('out', 'PRT'), ('out', 'ADV')),
#  (('le', 'NUM'), ('le', 'DET')),
#  (('genie', 'NUM'), ('genie', 'NOUN')),
#  (('back', 'PRT'), ('back', 'ADV')),
#  (('len', 'NUM'), ('len', 'NOUN')),
#  (('foldability', 'NUM'), ('foldability', 'NOUN')),
#  (('inserted', 'NUM'), ('inserted', 'VERB')),
#  (('incisions', 'NUM'), ('incisions', 'NOUN')),
#  (('eye', 'NUM'), ('eye', 'NOUN')),
#  (('care', 'VERB'), ('care', 'NOUN')),
#  (('clear', 'ADJ'), ('clear', 'VERB')),
#  (('ethanol', 'NUM'), ('ethanol', 'NOUN')),
#  (('fuel', 'NOUN'), ('fuel', 'VERB')),
#  (('fleet', 'NUM'), ('fleet', 'NOUN')),
#  (('Lucille', 'NUM'), ('Lucille', 'NOUN')),
#  (('84-year-old', 'NUM'), ('84-year-old', 'ADJ')),
#  (('housewife', 'NUM'), ('housewife', 'NOUN')),
#  (('amazingly', 'NUM'), ('amazingly', 'ADV')),
#  (('jolts', 'NUM'), ('jolts', 'NOUN')),
#  (('DISCOUNT', 'NUM'), ('DISCOUNT', 'NOUN')),
#  (('sight', 'NUM'), ('sight', 'NOUN')),
#  (('*T*-178', 'NUM'), ('*T*-178', 'X')),
#  (('Kirkpatrick', 'NUM'), ('Kirkpatrick', 'NOUN')),
#  (('*-154', 'NUM'), ('*-154', 'X')),
#  (('Sumitomo', 'NUM'), ('Sumitomo', 'NOUN')),
#  (('Metal', 'NUM'), ('Metal', 'NOUN')),
#  (('individual', 'ADJ'), ('individual', 'NOUN')),
#  (('readings', 'NUM'), ('readings', 'NOUN')),
#  (('wrestling', 'NUM'), ('wrestling', 'VERB')),
#  (('intelligent', 'NUM'), ('intelligent', 'ADJ')),
#  (('insane', 'NUM'), ('insane', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('tailor-made', 'NUM'), ('tailor-made', 'ADJ')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('purhasing', 'NUM'), ('purhasing', 'NOUN')),
#  (('report', 'VERB'), ('report', 'NOUN')),
#  (('movies', 'NUM'), ('movies', 'NOUN')),
#  (('Peck', 'NUM'), ('Peck', 'NOUN')),
#  (('marvelously', 'NUM'), ('marvelously', 'ADV')),
#  (('loose', 'NUM'), ('loose', 'ADJ')),
#  (('portrayal', 'NUM'), ('portrayal', 'NOUN')),
#  (('work', 'VERB'), ('work', 'NOUN')),
#  (('force', 'VERB'), ('force', 'NOUN')),
#  (('Cataracts', 'NUM'), ('Cataracts', 'NOUN')),
#  (('refer', 'NUM'), ('refer', 'VERB')),
#  (('clouding', 'NUM'), ('clouding', 'NOUN')),
#  (('eye', 'NUM'), ('eye', 'NOUN')),
#  (('*-107', 'NUM'), ('*-107', 'X')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('maturing', 'NUM'), ('maturing', 'VERB')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('filled', 'NUM'), ('filled', 'VERB')),
#  (('solemn', 'NUM'), ('solemn', 'ADJ')),
#  (('intoxication', 'NUM'), ('intoxication', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-226', 'NUM'), ('*T*-226', 'X')),
#  (('intricate', 'NUM'), ('intricate', 'ADJ')),
#  (('ritual', 'NUM'), ('ritual', 'NOUN')),
#  (('faultlessly', 'NUM'), ('faultlessly', 'ADV')),
#  (('properties', 'NUM'), ('properties', 'NOUN')),
#  (('Indexing', 'NUM'), ('Indexing', 'NOUN')),
#  (('barometer', 'NUM'), ('barometer', 'NOUN')),
#  (('panic', 'NOUN'), ('panic', 'VERB')),
#  (('so', 'ADV'), ('so', 'ADP')),
#  (('crying', 'NUM'), ('crying', 'VERB')),
#  (('assistant', 'NOUN'), ('assistant', 'ADJ')),
#  (('Ilminster', 'NUM'), ('Ilminster', 'NOUN')),
#  (('Somerset', 'NUM'), ('Somerset', 'NOUN')),
#  (('following', 'NOUN'), ('following', 'VERB')),
#  (('dust-up', 'NUM'), ('dust-up', 'NOUN')),
#  (('attendance', 'NUM'), ('attendance', 'NOUN')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('shown', 'NUM'), ('shown', 'VERB')),
#  (('no', 'X'), ('no', 'DET')),
#  (('sign', 'VERB'), ('sign', 'NOUN')),
#  (('Video', 'NUM'), ('Video', 'NOUN')),
#  (('Tip', 'NUM'), ('Tip', 'NOUN')),
#  (('finest', 'NUM'), ('finest', 'ADJ')),
#  (('defeats', 'NUM'), ('defeats', 'VERB')),
#  (('inkling', 'NUM'), ('inkling', 'NOUN')),
#  (('underprivileged', 'NUM'), ('underprivileged', 'ADJ')),
#  (('prosecutor', 'NUM'), ('prosecutor', 'NOUN')),
#  (('*T*-96', 'NUM'), ('*T*-96', 'X')),
#  (('alumni', 'NUM'), ('alumni', 'NOUN')),
#  (('cultivated', 'NUM'), ('cultivated', 'VERB')),
#  (('much', 'ADJ'), ('much', 'ADV')),
#  (('savvier', 'NUM'), ('savvier', 'ADJ')),
#  (('much', 'ADV'), ('much', 'ADJ')),
#  (('burned', 'NUM'), ('burned', 'VERB')),
#  (('wrath', 'NUM'), ('wrath', 'NOUN')),
#  (('Californian', 'NUM'), ('Californian', 'NOUN')),
#  (('Bolivia', 'NUM'), ('Bolivia', 'NOUN')),
#  (('broadened', 'NUM'), ('broadened', 'VERB')),
#  (('initiate', 'NUM'), ('initiate', 'NOUN')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('R.D.', 'NUM'), ('R.D.', 'NOUN')),
#  (('Vos', 'NUM'), ('Vos', 'NOUN')),
#  (('N.Y', 'NUM'), ('N.Y', 'NOUN')),
#  (('delayed', 'NUM'), ('delayed', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('Above', 'NUM'), ('Above', 'ADP')),
#  (('confused', 'ADJ'), ('confused', 'VERB')),
#  (('around', 'ADP'), ('around', 'PRT')),
#  (('accountants', 'NUM'), ('accountants', 'NOUN')),
#  (('blinks', 'NUM'), ('blinks', 'VERB')),
#  (('eye', 'NUM'), ('eye', 'NOUN')),
#  (('bar', 'NOUN'), ('bar', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('abortion-related', 'NUM'), ('abortion-related', 'ADJ')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('further', 'ADJ'), ('further', 'ADV')),
#  (('load', 'NOUN'), ('load', 'VERB')),
#  (('dreamed', 'NUM'), ('dreamed', 'VERB')),
#  (('improbable', 'NUM'), ('improbable', 'ADJ')),
#  (('shop', 'NUM'), ('shop', 'NOUN')),
#  (('high-rise', 'NUM'), ('high-rise', 'ADJ')),
#  (('help', 'VERB'), ('help', 'NOUN')),
#  (('diagram', 'NUM'), ('diagram', 'NOUN')),
#  (('arrows', 'NUM'), ('arrows', 'NOUN')),
#  (('polystyrene', 'NUM'), ('polystyrene', 'NOUN')),
#  (('foam', 'NUM'), ('foam', 'NOUN')),
#  (('polyproplene', 'NUM'), ('polyproplene', 'NOUN')),
#  (('polyester', 'NUM'), ('polyester', 'NOUN')),
#  (('plastic', 'ADJ'), ('plastic', 'NOUN')),
#  (('non-biodegradable', 'NUM'), ('non-biodegradable', 'ADJ')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('seventh', 'NUM'), ('seventh', 'ADJ')),
#  (('Researchers', 'NUM'), ('Researchers', 'NOUN')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('closer', 'ADV'), ('closer', 'ADJ')),
#  (('unwilling', 'NUM'), ('unwilling', 'ADJ')),
#  (('manpower', 'NUM'), ('manpower', 'NOUN')),
#  (('removing', 'NUM'), ('removing', 'VERB')),
#  (('safeguarding', 'NUM'), ('safeguarding', 'VERB')),
#  (('Anku', 'NUM'), ('Anku', 'NOUN')),
#  (('Ketchum', 'NUM'), ('Ketchum', 'NOUN')),
#  (('Braun', 'NUM'), ('Braun', 'NOUN')),
#  (('investor-relations', 'NUM'), ('investor-relations', 'NOUN')),
#  (('marketing-communications', 'NUM'), ('marketing-communications', 'NOUN')),
#  (('headed', 'NUM'), ('headed', 'VERB')),
#  (('curbed', 'NUM'), ('curbed', 'VERB')),
#  (('index-fund', 'NOUN'), ('index-fund', 'ADJ')),
#  (('leveraging', 'NUM'), ('leveraging', 'VERB')),
#  (('owning', 'NUM'), ('owning', 'VERB')),
#  (('own', 'ADJ'), ('own', 'VERB')),
#  (('flirted', 'NUM'), ('flirted', 'VERB')),
#  (('charge', 'NOUN'), ('charge', 'VERB')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('matters', 'NOUN'), ('matters', 'VERB')),
#  (('fine', 'NOUN'), ('fine', 'ADV')),
#  (('chief', 'NOUN'), ('chief', 'ADJ')),
#  (('*-152', 'NUM'), ('*-152', 'X')),
#  (('father-in-law', 'NUM'), ('father-in-law', 'NOUN')),
#  (('Gardner', 'NUM'), ('Gardner', 'NOUN')),
#  (('Hubbard', 'NUM'), ('Hubbard', 'NOUN')),
#  (('wealthy', 'NUM'), ('wealthy', 'ADJ')),
#  (('well-connected', 'NUM'), ('well-connected', 'ADJ')),
#  (('financing', 'VERB'), ('financing', 'NOUN')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('Moon', 'NUM'), ('Moon', 'NOUN')),
#  (('Landrieu', 'NUM'), ('Landrieu', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('cavernous', 'NUM'), ('cavernous', 'ADJ')),
#  (('money-losing', 'NUM'), ('money-losing', 'ADJ')),
#  (('benefits', 'NOUN'), ('benefits', 'VERB')),
#  (('relevance', 'NUM'), ('relevance', 'NOUN')),
#  (('U.S.', 'NOUN'), ('U.S.', 'ADJ')),
#  (('close', 'VERB'), ('close', 'NOUN')),
#  (('appeal', 'NOUN'), ('appeal', 'VERB')),
#  (('cleanup', 'NUM'), ('cleanup', 'NOUN')),
#  (('burn', 'NUM'), ('burn', 'VERB')),
#  (('cleaner-burning', 'NUM'), ('cleaner-burning', 'ADJ')),
#  (('fuels', 'NUM'), ('fuels', 'NOUN')),
#  (('overvalued', 'NUM'), ('overvalued', 'VERB')),
#  (('Paris', 'NUM'), ('Paris', 'NOUN')),
#  (('Brussels', 'NUM'), ('Brussels', 'NOUN')),
#  (('Milan', 'NUM'), ('Milan', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('discretion', 'NUM'), ('discretion', 'NOUN')),
#  (('select', 'NUM'), ('select', 'VERB')),
#  (('net', 'ADJ'), ('net', 'NOUN')),
#  (('unrestricted', 'NUM'), ('unrestricted', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*-165', 'NUM'), ('*-165', 'X')),
#  (('firm', 'NOUN'), ('firm', 'ADJ')),
#  (('opening', 'VERB'), ('opening', 'NOUN')),
#  (('tempted', 'NUM'), ('tempted', 'VERB')),
#  (('less', 'ADV'), ('less', 'ADJ')),
#  (('higher', 'ADJ'), ('higher', 'ADV')),
#  (('trading', 'NOUN'), ('trading', 'VERB')),
#  (('1980s', 'NUM'), ('1980s', 'NOUN')),
#  (('glory', 'NUM'), ('glory', 'NOUN')),
#  (('faded', 'NUM'), ('faded', 'VERB')),
#  (('yellow', 'NUM'), ('yellow', 'ADJ')),
#  (('bricks', 'NUM'), ('bricks', 'NOUN')),
#  (('facade', 'NUM'), ('facade', 'NOUN')),
#  (('record', 'NOUN'), ('record', 'ADJ')),
#  (('diagnosed', 'NUM'), ('diagnosed', 'VERB')),
#  (('half', 'DET'), ('half', 'NOUN')),
#  (('27-year', 'NUM'), ('27-year', 'ADJ')),
#  (('information-services', 'NUM'), ('information-services', 'NOUN')),
#  (('Southeast', 'NOUN'), ('Southeast', 'ADJ')),
#  (('uses', 'VERB'), ('uses', 'NOUN')),
#  (('cancer-causing', 'NUM'), ('cancer-causing', 'ADJ')),
#  (('outlawed', 'NUM'), ('outlawed', 'VERB')),
#  (('stemmed', 'NUM'), ('stemmed', 'VERB')),
#  (('post', 'VERB'), ('post', 'NOUN')),
#  (('directorship', 'NUM'), ('directorship', 'NOUN')),
#  (('little', 'ADJ'), ('little', 'ADV')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('what', 'PRON'), ('what', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-117', 'NUM'), ('*T*-117', 'X')),
#  (('uptick', 'NOUN'), ('uptick', 'VERB')),
#  (('head', 'NOUN'), ('head', 'ADJ')),
#  (('Silverman', 'NUM'), ('Silverman', 'NOUN')),
#  (('insurance-company', 'NUM'), ('insurance-company', 'NOUN')),
#  (('comments', 'NOUN'), ('comments', 'VERB')),
#  (('increases', 'NOUN'), ('increases', 'VERB')),
#  (('jeopardy', 'NUM'), ('jeopardy', 'NOUN')),
#  (('NEW', 'NUM'), ('NEW', 'NOUN')),
#  (('ACCOUNT', 'NUM'), ('ACCOUNT', 'NOUN')),
#  (('Chilver', 'NUM'), ('Chilver', 'NOUN')),
#  (('63-year-old', 'NUM'), ('63-year-old', 'ADJ')),
#  (('English', 'ADJ'), ('English', 'NOUN')),
#  (('Clays', 'NUM'), ('Clays', 'NOUN')),
#  (('CoreStates', 'NUM'), ('CoreStates', 'NOUN')),
#  (('Earle', 'NUM'), ('Earle', 'NOUN')),
#  (('Palmer', 'NUM'), ('Palmer', 'NOUN')),
#  (('Spiro', 'NUM'), ('Spiro', 'NOUN')),
#  (('account', 'VERB'), ('account', 'NOUN')),
#  (('there', 'DET'), ('there', 'ADV')),
#  (('what', 'PRON'), ('what', 'DET')),
#  (('escape', 'NUM'), ('escape', 'NOUN')),
#  (('open', 'VERB'), ('open', 'ADJ')),
#  (('drink', 'VERB'), ('drink', 'NOUN')),
#  (('insanity', 'NUM'), ('insanity', 'NOUN')),
#  (('heirs', 'NUM'), ('heirs', 'NOUN')),
#  (('Nylev', 'NUM'), ('Nylev', 'NOUN')),
#  (('up', 'ADV'), ('up', 'ADP')),
#  (('malnutrition', 'NUM'), ('malnutrition', 'NOUN')),
#  (('chest', 'NUM'), ('chest', 'NOUN')),
#  (('cardiovascular', 'NUM'), ('cardiovascular', 'ADJ')),
#  (('infectious', 'NUM'), ('infectious', 'ADJ')),
#  (('aftereffects', 'NUM'), ('aftereffects', 'NOUN')),
#  (('assaults', 'NUM'), ('assaults', 'NOUN')),
#  (('*T*-91', 'NUM'), ('*T*-91', 'X')),
#  (('grandstander', 'NUM'), ('grandstander', 'NOUN')),
#  (('luxury', 'NUM'), ('luxury', 'NOUN')),
#  (('guarantee', 'VERB'), ('guarantee', 'NOUN')),
#  (('operating', 'NOUN'), ('operating', 'VERB')),
#  (('shopped', 'NUM'), ('shopped', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('half', 'DET'), ('half', 'NOUN')),
#  (('espouse', 'NUM'), ('espouse', 'VERB')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('one-third', 'NOUN'), ('one-third', 'ADJ')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('deteriorating', 'NUM'), ('deteriorating', 'VERB')),
#  (('Anderson', 'NUM'), ('Anderson', 'NOUN')),
#  (('59-year-old', 'NUM'), ('59-year-old', 'ADJ')),
#  (('fluctuations', 'NUM'), ('fluctuations', 'NOUN')),
#  (('heebie-jeebies', 'NUM'), ('heebie-jeebies', 'NOUN')),
#  (('much', 'ADV'), ('much', 'ADJ')),
#  (('point', 'VERB'), ('point', 'NOUN')),
#  (('outlawing', 'NUM'), ('outlawing', 'VERB')),
#  (('audit', 'VERB'), ('audit', 'NOUN')),
#  (('stand', 'VERB'), ('stand', 'NOUN')),
#  (('display', 'NUM'), ('display', 'VERB')),
#  (('projector', 'NUM'), ('projector', 'NOUN')),
#  (('underline', 'NUM'), ('underline', 'VERB')),
#  (('Old-House', 'NUM'), ('Old-House', 'NOUN')),
#  (('publishing', 'VERB'), ('publishing', 'NOUN')),
#  (('all', 'DET'), ('all', 'ADV')),
#  (('following', 'VERB'), ('following', 'NOUN')),
#  (('round-trip', 'NUM'), ('round-trip', 'ADJ')),
#  (('Trans', 'NUM'), ('Trans', 'NOUN')),
#  (('luxury', 'NUM'), ('luxury', 'NOUN')),
#  (('soaring', 'NUM'), ('soaring', 'VERB')),
#  (('reclaimed', 'NUM'), ('reclaimed', 'VERB')),
#  (('240-page', 'NUM'), ('240-page', 'ADJ')),
#  (('Iran-Contra', 'NUM'), ('Iran-Contra', 'NOUN')),
#  (('Next', 'NUM'), ('Next', 'ADJ')),
#  (('Philippine', 'NUM'), ('Philippine', 'NOUN')),
#  (('launch', 'VERB'), ('launch', 'NOUN')),
#  (('capped', 'ADJ'), ('capped', 'VERB')),
#  (('Philippine', 'NUM'), ('Philippine', 'ADJ')),
#  (('Corazon', 'NUM'), ('Corazon', 'NOUN')),
#  (('Aquino', 'NUM'), ('Aquino', 'NOUN')),
#  (('the', 'DET'), ('the', 'NOUN')),
#  (('midyear', 'NUM'), ('midyear', 'NOUN')),
#  (('Spending', 'NUM'), ('Spending', 'NOUN')),
#  (('nonresidential', 'NUM'), ('nonresidential', 'ADJ')),
#  (('off', 'PRT'), ('off', 'ADJ')),
#  (('awaits', 'NUM'), ('awaits', 'VERB')),
#  (('point', 'NOUN'), ('point', 'VERB')),
#  (('Aerospace', 'NUM'), ('Aerospace', 'NOUN')),
#  (('sagged', 'NUM'), ('sagged', 'VERB')),
#  (('B-1B', 'ADJ'), ('B-1B', 'NOUN')),
#  (('bombers', 'NUM'), ('bombers', 'NOUN')),
#  (('out', 'PRT'), ('out', 'ADP')),
#  (('half', 'NOUN'), ('half', 'DET')),
#  (('earlier', 'ADV'), ('earlier', 'ADJ')),
#  (('shipboard', 'NUM'), ('shipboard', 'NOUN')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('Soviet', 'ADJ'), ('Soviet', 'NOUN')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('Malta', 'NUM'), ('Malta', 'NOUN')),
#  (('NCNB', 'NUM'), ('NCNB', 'NOUN')),
#  (('Connections', 'NUM'), ('Connections', 'NOUN')),
#  (('adults', 'NUM'), ('adults', 'NOUN')),
#  (('broadly', 'NUM'), ('broadly', 'ADV')),
#  (('construed', 'NUM'), ('construed', 'VERB')),
#  (('emasculate', 'NUM'), ('emasculate', 'VERB')),
#  (('swallow', 'NUM'), ('swallow', 'VERB')),
#  (('contrary', 'NOUN'), ('contrary', 'ADJ')),
#  (('the', 'DET'), ('the', 'NUM'))]

# %% [markdown]
# ## 4.  Solve the problem of unknown words

# %% [markdown]
# ###  Modification 1 - Lexicon based (tagging unknown words with the most common tag)

# %%
#Lexicon based model

# Obtain most frequent tag to assign it for the unknown words

most_frequent_tag = collections.Counter([tup[1] for tup in train_tagged_words]).most_common(1)[0][0]
most_frequent_tag
# Out:
# 'NOUN'

# %%
# Viterbi Heuristic with lexicon

def Viterbi_mod1(words, train_bag = train_tagged_words):
    state = []    
    unique_tags_list = list(unique_tags)
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in unique_tags:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]  
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        pmax = max(p)
        # getting state for which probability is maximum
        if pmax == 0:
            state.append(most_frequent_tag)  # assigning most frequent tag to the unknown words
        else:
            state_max = unique_tags_list[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %%
# Tagging with Lexicon based viterbi

tagged_seq_mod1 = Viterbi_mod1(test_tagged_words)

# %% [markdown]
# ### Evaluating tagging accuracy

# %%
test_run_base_mod1 = [tup for sent in test_set for tup in sent]
correctly_tagged_mod1 = [i for i, j in zip(tagged_seq_mod1, test_run_base_mod1) if i == j] 

accuracy_mod1 = len(correctly_tagged_mod1)/len(tagged_seq_mod1)
print("Lexicon based Viterbi Accuracy -----> ",accuracy_mod1)
# Out:
# Lexicon based Viterbi Accuracy ----->  0.9348423947535435

# %%
#List of incorrectly tagged words
incorrect_tagged_cases_mod1 = [j for i, j in enumerate(zip(tagged_seq_mod1, test_run_base_mod1)) if j[0]!=j[1]]
incorrect_tagged_cases_mod1
# Out:
# [(('book', 'NOUN'), ('book', 'VERB')),
#  (('stocks', 'NOUN'), ('stocks', 'ADV')),
#  (('up', 'PRT'), ('up', 'ADP')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('ignored', 'NOUN'), ('ignored', 'VERB')),
#  (('mine', 'NOUN'), ('mine', 'ADJ')),
#  (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN')),
#  (('first', 'ADJ'), ('first', 'ADV')),
#  (('clamped', 'NOUN'), ('clamped', 'VERB')),
#  (('third-largest', 'NOUN'), ('third-largest', 'ADJ')),
#  (('fifth-largest', 'NOUN'), ('fifth-largest', 'ADJ')),
#  (('89.7', 'NOUN'), ('89.7', 'NUM')),
#  (('141.9', 'NOUN'), ('141.9', 'NUM')),
#  (('94.8', 'NOUN'), ('94.8', 'NUM')),
#  (('149.9', 'NOUN'), ('149.9', 'NUM')),
#  (('argues', 'NOUN'), ('argues', 'VERB')),
#  (('Sit', 'NOUN'), ('Sit', 'VERB')),
#  (('down', 'ADP'), ('down', 'ADV')),
#  (('British', 'ADJ'), ('British', 'NOUN')),
#  (('halt', 'NOUN'), ('halt', 'VERB')),
#  (('slides', 'NOUN'), ('slides', 'VERB')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('athletic', 'NOUN'), ('athletic', 'ADJ')),
#  (('to', 'PRT'), ('to', 'ADJ')),
#  (('better', 'ADJ'), ('better', 'ADV')),
#  (('illustrates', 'NOUN'), ('illustrates', 'VERB')),
#  (('attempt', 'VERB'), ('attempt', 'NOUN')),
#  (('usurp', 'NOUN'), ('usurp', 'VERB')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('609', 'NOUN'), ('609', 'NUM')),
#  (('administer', 'NOUN'), ('administer', 'VERB')),
#  (('disapproved', 'NOUN'), ('disapproved', 'VERB')),
#  (('*-58', 'NOUN'), ('*-58', 'X')),
#  (('applicable', 'NOUN'), ('applicable', 'ADJ')),
#  (('Five', 'NOUN'), ('Five', 'NUM')),
#  (('Proper', 'NOUN'), ('Proper', 'ADJ')),
#  (('English', 'NOUN'), ('English', 'ADJ')),
#  (('highest-pitched', 'NOUN'), ('highest-pitched', 'ADJ')),
#  (('descending', 'NOUN'), ('descending', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('62-year-old', 'NOUN'), ('62-year-old', 'ADJ')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('unsolicited', 'NOUN'), ('unsolicited', 'ADJ')),
#  (('3.19', 'NOUN'), ('3.19', 'NUM')),
#  (('bid', 'VERB'), ('bid', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('diversified', 'ADJ'), ('diversified', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('impressive', 'NOUN'), ('impressive', 'ADJ')),
#  (('issue', 'NOUN'), ('issue', 'VERB')),
#  (('29year', 'NOUN'), ('29year', 'ADJ')),
#  (('nine-month', 'NOUN'), ('nine-month', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('ECONOMIC', 'NOUN'), ('ECONOMIC', 'ADJ')),
#  (('APPEARS', 'NOUN'), ('APPEARS', 'VERB')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('U.S.-Japanese', 'NOUN'), ('U.S.-Japanese', 'ADJ')),
#  (('*T*-174', 'NOUN'), ('*T*-174', 'X')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-175', 'NOUN'), ('*T*-175', 'X')),
#  (('up', 'ADV'), ('up', 'ADP')),
#  (('past', 'ADJ'), ('past', 'NOUN')),
#  (('senior', 'ADJ'), ('senior', 'NOUN')),
#  (('speculate', 'NOUN'), ('speculate', 'VERB')),
#  (('yen-support', 'NOUN'), ('yen-support', 'ADJ')),
#  (('150.00', 'NOUN'), ('150.00', 'NUM')),
#  (('excess', 'ADJ'), ('excess', 'NOUN')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('rebound', 'VERB'), ('rebound', 'NOUN')),
#  (('pushes', 'NOUN'), ('pushes', 'VERB')),
#  (('Left', 'NOUN'), ('Left', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('so', 'ADP'), ('so', 'ADV')),
#  (('much', 'ADJ'), ('much', 'ADV')),
#  (('preclinical', 'NOUN'), ('preclinical', 'ADJ')),
#  (('vague', 'NOUN'), ('vague', 'ADJ')),
#  (('mushy', 'NOUN'), ('mushy', 'ADJ')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('out', 'PRT'), ('out', 'ADV')),
#  (('le', 'NOUN'), ('le', 'DET')),
#  (('115', 'NOUN'), ('115', 'NUM')),
#  (('back', 'PRT'), ('back', 'ADV')),
#  (('inserted', 'NOUN'), ('inserted', 'VERB')),
#  (('care', 'VERB'), ('care', 'NOUN')),
#  (('care', 'VERB'), ('care', 'NOUN')),
#  (('clear', 'ADJ'), ('clear', 'VERB')),
#  (('fuel', 'NOUN'), ('fuel', 'VERB')),
#  (('84-year-old', 'NOUN'), ('84-year-old', 'ADJ')),
#  (('amazingly', 'NOUN'), ('amazingly', 'ADV')),
#  (('*T*-178', 'NOUN'), ('*T*-178', 'X')),
#  (('*-154', 'NOUN'), ('*-154', 'X')),
#  (('692', 'NOUN'), ('692', 'NUM')),
#  (('960', 'NOUN'), ('960', 'NUM')),
#  (('individual', 'ADJ'), ('individual', 'NOUN')),
#  (('51.6', 'NOUN'), ('51.6', 'NUM')),
#  (('wrestling', 'NOUN'), ('wrestling', 'VERB')),
#  (('intelligent', 'NOUN'), ('intelligent', 'ADJ')),
#  (('insane', 'NOUN'), ('insane', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('tailor-made', 'NOUN'), ('tailor-made', 'ADJ')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('report', 'VERB'), ('report', 'NOUN')),
#  (('marvelously', 'NOUN'), ('marvelously', 'ADV')),
#  (('loose', 'NOUN'), ('loose', 'ADJ')),
#  (('work', 'VERB'), ('work', 'NOUN')),
#  (('force', 'VERB'), ('force', 'NOUN')),
#  (('refer', 'NOUN'), ('refer', 'VERB')),
#  (('*-107', 'NOUN'), ('*-107', 'X')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('maturing', 'NOUN'), ('maturing', 'VERB')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('filled', 'NOUN'), ('filled', 'VERB')),
#  (('solemn', 'NOUN'), ('solemn', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-226', 'NOUN'), ('*T*-226', 'X')),
#  (('intricate', 'NOUN'), ('intricate', 'ADJ')),
#  (('faultlessly', 'NOUN'), ('faultlessly', 'ADV')),
#  (('panic', 'NOUN'), ('panic', 'VERB')),
#  (('so', 'ADV'), ('so', 'ADP')),
#  (('crying', 'NOUN'), ('crying', 'VERB')),
#  (('assistant', 'NOUN'), ('assistant', 'ADJ')),
#  (('following', 'NOUN'), ('following', 'VERB')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('8.75', 'NOUN'), ('8.75', 'NUM')),
#  (('shown', 'NOUN'), ('shown', 'VERB')),
#  (('finest', 'NOUN'), ('finest', 'ADJ')),
#  (('472', 'NOUN'), ('472', 'NUM')),
#  (('defeats', 'NOUN'), ('defeats', 'VERB')),
#  (('underprivileged', 'NOUN'), ('underprivileged', 'ADJ')),
#  (('*T*-96', 'NOUN'), ('*T*-96', 'X')),
#  (('cultivated', 'NOUN'), ('cultivated', 'VERB')),
#  (('much', 'ADJ'), ('much', 'ADV')),
#  (('savvier', 'NOUN'), ('savvier', 'ADJ')),
#  (('much', 'ADV'), ('much', 'ADJ')),
#  (('burned', 'NOUN'), ('burned', 'VERB')),
#  (('broadened', 'NOUN'), ('broadened', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('delayed', 'NOUN'), ('delayed', 'VERB')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('Above', 'NOUN'), ('Above', 'ADP')),
#  (('confused', 'ADJ'), ('confused', 'VERB')),
#  (('around', 'ADP'), ('around', 'PRT')),
#  (('blinks', 'NOUN'), ('blinks', 'VERB')),
#  (('bar', 'NOUN'), ('bar', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('abortion-related', 'NOUN'), ('abortion-related', 'ADJ')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('further', 'ADJ'), ('further', 'ADV')),
#  (('load', 'NOUN'), ('load', 'VERB')),
#  (('dreamed', 'NOUN'), ('dreamed', 'VERB')),
#  (('improbable', 'NOUN'), ('improbable', 'ADJ')),
#  (('high-rise', 'NOUN'), ('high-rise', 'ADJ')),
#  (('help', 'VERB'), ('help', 'NOUN')),
#  (('plastic', 'ADJ'), ('plastic', 'NOUN')),
#  (('non-biodegradable', 'NOUN'), ('non-biodegradable', 'ADJ')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('seventh', 'NOUN'), ('seventh', 'ADJ')),
#  (("'82", 'NOUN'), ("'82", 'NUM')),
#  (('115', 'NOUN'), ('115', 'NUM')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('closer', 'ADV'), ('closer', 'ADJ')),
#  (('unwilling', 'NOUN'), ('unwilling', 'ADJ')),
#  (('removing', 'NOUN'), ('removing', 'VERB')),
#  (('safeguarding', 'NOUN'), ('safeguarding', 'VERB')),
#  (('headed', 'NOUN'), ('headed', 'VERB')),
#  (('curbed', 'NOUN'), ('curbed', 'VERB')),
#  (('index-fund', 'NOUN'), ('index-fund', 'ADJ')),
#  (('leveraging', 'NOUN'), ('leveraging', 'VERB')),
#  (('owning', 'NOUN'), ('owning', 'VERB')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('own', 'ADJ'), ('own', 'VERB')),
#  (('flirted', 'NOUN'), ('flirted', 'VERB')),
#  (('charge', 'NOUN'), ('charge', 'VERB')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('matters', 'NOUN'), ('matters', 'VERB')),
#  (('fine', 'NOUN'), ('fine', 'ADV')),
#  (('chief', 'NOUN'), ('chief', 'ADJ')),
#  (('*-152', 'NOUN'), ('*-152', 'X')),
#  (('wealthy', 'NOUN'), ('wealthy', 'ADJ')),
#  (('well-connected', 'NOUN'), ('well-connected', 'ADJ')),
#  (('financing', 'VERB'), ('financing', 'NOUN')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('cavernous', 'NOUN'), ('cavernous', 'ADJ')),
#  (('money-losing', 'NOUN'), ('money-losing', 'ADJ')),
#  (('benefits', 'NOUN'), ('benefits', 'VERB')),
#  (('U.S.', 'NOUN'), ('U.S.', 'ADJ')),
#  (('143.93', 'NOUN'), ('143.93', 'NUM')),
#  (('close', 'VERB'), ('close', 'NOUN')),
#  (('143.08', 'NOUN'), ('143.08', 'NUM')),
#  (('appeal', 'NOUN'), ('appeal', 'VERB')),
#  (('burn', 'NOUN'), ('burn', 'VERB')),
#  (('cleaner-burning', 'NOUN'), ('cleaner-burning', 'ADJ')),
#  (('858,000', 'NOUN'), ('858,000', 'NUM')),
#  (('overvalued', 'NOUN'), ('overvalued', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('select', 'NOUN'), ('select', 'VERB')),
#  (('net', 'ADJ'), ('net', 'NOUN')),
#  (('306', 'NOUN'), ('306', 'NUM')),
#  (('unrestricted', 'NOUN'), ('unrestricted', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*-165', 'NOUN'), ('*-165', 'X')),
#  (('firm', 'NOUN'), ('firm', 'ADJ')),
#  (('opening', 'VERB'), ('opening', 'NOUN')),
#  (('tempted', 'NOUN'), ('tempted', 'VERB')),
#  (('less', 'ADV'), ('less', 'ADJ')),
#  (('higher', 'ADJ'), ('higher', 'ADV')),
#  (('trading', 'NOUN'), ('trading', 'VERB')),
#  (('1980s', 'NUM'), ('1980s', 'NOUN')),
#  (('faded', 'NOUN'), ('faded', 'VERB')),
#  (('yellow', 'NOUN'), ('yellow', 'ADJ')),
#  (('record', 'NOUN'), ('record', 'ADJ')),
#  (('550,000', 'NOUN'), ('550,000', 'NUM')),
#  (('Four', 'NOUN'), ('Four', 'NUM')),
#  (('diagnosed', 'NOUN'), ('diagnosed', 'VERB')),
#  (('half', 'DET'), ('half', 'NOUN')),
#  (('27-year', 'NOUN'), ('27-year', 'ADJ')),
#  (('Southeast', 'NOUN'), ('Southeast', 'ADJ')),
#  (('1997', 'NOUN'), ('1997', 'NUM')),
#  (('uses', 'VERB'), ('uses', 'NOUN')),
#  (('cancer-causing', 'NOUN'), ('cancer-causing', 'ADJ')),
#  (('outlawed', 'NOUN'), ('outlawed', 'VERB')),
#  (('stemmed', 'NOUN'), ('stemmed', 'VERB')),
#  (('post', 'VERB'), ('post', 'NOUN')),
#  (('little', 'ADJ'), ('little', 'ADV')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('what', 'PRON'), ('what', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-117', 'NOUN'), ('*T*-117', 'X')),
#  (('uptick', 'NOUN'), ('uptick', 'VERB')),
#  (('head', 'NOUN'), ('head', 'ADJ')),
#  (('comments', 'NOUN'), ('comments', 'VERB')),
#  (('increases', 'NOUN'), ('increases', 'VERB')),
#  (('14.75', 'NOUN'), ('14.75', 'NUM')),
#  (('63-year-old', 'NOUN'), ('63-year-old', 'ADJ')),
#  (('English', 'ADJ'), ('English', 'NOUN')),
#  (('account', 'VERB'), ('account', 'NOUN')),
#  (('there', 'DET'), ('there', 'ADV')),
#  (('what', 'PRON'), ('what', 'DET')),
#  (('open', 'VERB'), ('open', 'ADJ')),
#  (('drink', 'VERB'), ('drink', 'NOUN')),
#  (('up', 'ADV'), ('up', 'ADP')),
#  (('cardiovascular', 'NOUN'), ('cardiovascular', 'ADJ')),
#  (('infectious', 'NOUN'), ('infectious', 'ADJ')),
#  (('*T*-91', 'NOUN'), ('*T*-91', 'X')),
#  (('879', 'NOUN'), ('879', 'NUM')),
#  (('13.90', 'NOUN'), ('13.90', 'NUM')),
#  (('guarantee', 'VERB'), ('guarantee', 'NOUN')),
#  (('operating', 'NOUN'), ('operating', 'VERB')),
#  (('shopped', 'NOUN'), ('shopped', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('half', 'DET'), ('half', 'NOUN')),
#  (('espouse', 'NOUN'), ('espouse', 'VERB')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('one-third', 'NOUN'), ('one-third', 'ADJ')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('deteriorating', 'NOUN'), ('deteriorating', 'VERB')),
#  (('59-year-old', 'NOUN'), ('59-year-old', 'ADJ')),
#  (('much', 'ADV'), ('much', 'ADJ')),
#  (('point', 'VERB'), ('point', 'NOUN')),
#  (('outlawing', 'NOUN'), ('outlawing', 'VERB')),
#  (('audit', 'VERB'), ('audit', 'NOUN')),
#  (('stand', 'VERB'), ('stand', 'NOUN')),
#  (('display', 'NOUN'), ('display', 'VERB')),
#  (('underline', 'NOUN'), ('underline', 'VERB')),
#  (('publishing', 'VERB'), ('publishing', 'NOUN')),
#  (('126,000', 'NOUN'), ('126,000', 'NUM')),
#  (('all', 'DET'), ('all', 'ADV')),
#  (('following', 'VERB'), ('following', 'NOUN')),
#  (('round-trip', 'NOUN'), ('round-trip', 'ADJ')),
#  (('soaring', 'NOUN'), ('soaring', 'VERB')),
#  (('reclaimed', 'NOUN'), ('reclaimed', 'VERB')),
#  (('240-page', 'NOUN'), ('240-page', 'ADJ')),
#  (('221.4', 'NOUN'), ('221.4', 'NUM')),
#  (('Next', 'NOUN'), ('Next', 'ADJ')),
#  (('launch', 'VERB'), ('launch', 'NOUN')),
#  (('capped', 'ADJ'), ('capped', 'VERB')),
#  (('Philippine', 'NOUN'), ('Philippine', 'ADJ')),
#  (('the', 'DET'), ('the', 'NOUN')),
#  (('nonresidential', 'NOUN'), ('nonresidential', 'ADJ')),
#  (('off', 'PRT'), ('off', 'ADJ')),
#  (('99.1', 'NOUN'), ('99.1', 'NUM')),
#  (('awaits', 'NOUN'), ('awaits', 'VERB')),
#  (('point', 'NOUN'), ('point', 'VERB')),
#  (('sagged', 'NOUN'), ('sagged', 'VERB')),
#  (('B-1B', 'ADJ'), ('B-1B', 'NOUN')),
#  (('out', 'PRT'), ('out', 'ADP')),
#  (('half', 'NOUN'), ('half', 'DET')),
#  (('88.32', 'NOUN'), ('88.32', 'NUM')),
#  (('618.1', 'NOUN'), ('618.1', 'NUM')),
#  (('77.6', 'NOUN'), ('77.6', 'NUM')),
#  (('earlier', 'ADV'), ('earlier', 'ADJ')),
#  (('12.52', 'NOUN'), ('12.52', 'NUM')),
#  (('11.95', 'NOUN'), ('11.95', 'NUM')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('Soviet', 'ADJ'), ('Soviet', 'NOUN')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('broadly', 'NOUN'), ('broadly', 'ADV')),
#  (('construed', 'NOUN'), ('construed', 'VERB')),
#  (('emasculate', 'NOUN'), ('emasculate', 'VERB')),
#  (('swallow', 'NOUN'), ('swallow', 'VERB')),
#  (('contrary', 'NOUN'), ('contrary', 'ADJ')),
#  (('the', 'DET'), ('the', 'NUM'))]

# %% [markdown]
# ### Modification 2 - Rule based POS tagging

# %%
#Rule based model

#Define Rules
patterns = [
    (r'.*ing$', 'VERB'),              # gerund
    (r'.*ed$', 'VERB'),               # past tense
    (r'.*es$', 'VERB'),               # 3rd singular present
    (r'.*ould$', 'VERB'),              # modals
    (r'.*\'s$', 'NOUN'),              # possessive nouns
    (r'.*s$', 'NOUN'),                # plural nouns
    (r'^-?[0-9]+(.[0-9]+)?$', 'NUM'),
    (r'^(the|a)$', 'DET'),# cardinal numbers
    (r'.*', 'NOUN')
    # nouns
]

# Initiating a regex tagger 
regexp_tagger = nltk.RegexpTagger(patterns)

# %%
#Rule Based tagger

def tag_by_rules(word):
    tagged_by_rule = regexp_tagger.tag([word])
    return tagged_by_rule[0][1]

# %%
# Viterbi Heuristic with Rule based tagger
def Viterbi_mod2(words, train_bag = train_tagged_words):
    state = []    
    unique_tags_list = list(unique_tags)
    for key, word in enumerate(words):
        #initialise list of probability column for a given observation
        p = [] 
        for tag in unique_tags:
            if key == 0:
                transition_p = tags_df.loc['.', tag]
            else:
                transition_p = tags_df.loc[state[-1], tag]
                
            # compute emission and state probabilities
            emission_p = word_given_tag(words[key], tag)[0]/word_given_tag(words[key], tag)[1]  
            state_probability = emission_p * transition_p    
            p.append(state_probability)
        pmax = max(p)
        # getting state for which probability is maximum
        if pmax == 0:
            state.append(tag_by_rules(word))  # assigning most frequent tag to the unknown words
        else:
            state_max = unique_tags_list[p.index(pmax)] 
            state.append(state_max)
    return list(zip(words, state))

# %%
# Tagging with Rule based Viterbi

tagged_seq_mod2 = Viterbi_mod2(test_tagged_words)

# %% [markdown]
# #### Evaluating tagging accuracy

# %%
test_run_base_mod2 = [tup for sent in test_set for tup in sent]
correctly_tagged = [i for i, j in zip(tagged_seq_mod2, test_run_base_mod2) if i == j] 

accuracy_mod2 = len(correctly_tagged)/len(tagged_seq_mod2)
print("Rule based with Viterbi Accuracy------> ", accuracy_mod2)
# Out:
# Rule based with Viterbi Accuracy------>  0.946689232071081

# %%
#List of incorrectly tagged words
incorrect_tagged_cases_mod2 = [j for i, j in enumerate(zip(tagged_seq_mod2, test_run_base_mod2)) if j[0]!=j[1]]
incorrect_tagged_cases_mod2
# Out:
# [(('book', 'NOUN'), ('book', 'VERB')),
#  (('stocks', 'NOUN'), ('stocks', 'ADV')),
#  (('up', 'PRT'), ('up', 'ADP')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('mine', 'NOUN'), ('mine', 'ADJ')),
#  (('Palestinian', 'ADJ'), ('Palestinian', 'NOUN')),
#  (('first', 'ADJ'), ('first', 'ADV')),
#  (('third-largest', 'NOUN'), ('third-largest', 'ADJ')),
#  (('fifth-largest', 'NOUN'), ('fifth-largest', 'ADJ')),
#  (('Sit', 'NOUN'), ('Sit', 'VERB')),
#  (('down', 'ADP'), ('down', 'ADV')),
#  (('British', 'ADJ'), ('British', 'NOUN')),
#  (('halt', 'NOUN'), ('halt', 'VERB')),
#  (('slides', 'NOUN'), ('slides', 'VERB')),
#  (('most', 'ADJ'), ('most', 'ADV')),
#  (('athletic', 'NOUN'), ('athletic', 'ADJ')),
#  (('to', 'PRT'), ('to', 'ADJ')),
#  (('better', 'ADJ'), ('better', 'ADV')),
#  (('attempt', 'VERB'), ('attempt', 'NOUN')),
#  (('usurp', 'NOUN'), ('usurp', 'VERB')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('administer', 'NOUN'), ('administer', 'VERB')),
#  (('*-58', 'NOUN'), ('*-58', 'X')),
#  (('applicable', 'NOUN'), ('applicable', 'ADJ')),
#  (('Five', 'NOUN'), ('Five', 'NUM')),
#  (('Proper', 'NOUN'), ('Proper', 'ADJ')),
#  (('English', 'NOUN'), ('English', 'ADJ')),
#  (('highest-pitched', 'VERB'), ('highest-pitched', 'ADJ')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('62-year-old', 'NOUN'), ('62-year-old', 'ADJ')),
#  (('executive', 'NOUN'), ('executive', 'ADJ')),
#  (('unsolicited', 'VERB'), ('unsolicited', 'ADJ')),
#  (('bid', 'VERB'), ('bid', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('diversified', 'ADJ'), ('diversified', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('impressive', 'NOUN'), ('impressive', 'ADJ')),
#  (('issue', 'NOUN'), ('issue', 'VERB')),
#  (('29year', 'NOUN'), ('29year', 'ADJ')),
#  (('nine-month', 'NOUN'), ('nine-month', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('ECONOMIC', 'NOUN'), ('ECONOMIC', 'ADJ')),
#  (('APPEARS', 'NOUN'), ('APPEARS', 'VERB')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('U.S.-Japanese', 'NOUN'), ('U.S.-Japanese', 'ADJ')),
#  (('*T*-174', 'NOUN'), ('*T*-174', 'X')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-175', 'NOUN'), ('*T*-175', 'X')),
#  (('up', 'ADV'), ('up', 'ADP')),
#  (('past', 'ADJ'), ('past', 'NOUN')),
#  (('senior', 'ADJ'), ('senior', 'NOUN')),
#  (('speculate', 'NOUN'), ('speculate', 'VERB')),
#  (('yen-support', 'NOUN'), ('yen-support', 'ADJ')),
#  (('excess', 'ADJ'), ('excess', 'NOUN')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('smiles', 'VERB'), ('smiles', 'NOUN')),
#  (('rebound', 'VERB'), ('rebound', 'NOUN')),
#  (('Left', 'NOUN'), ('Left', 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('so', 'ADP'), ('so', 'ADV')),
#  (('much', 'ADJ'), ('much', 'ADV')),
#  (('preclinical', 'NOUN'), ('preclinical', 'ADJ')),
#  (('vague', 'NOUN'), ('vague', 'ADJ')),
#  (('mushy', 'NOUN'), ('mushy', 'ADJ')),
#  (('that', 'DET'), ('that', 'ADP')),
#  (('out', 'PRT'), ('out', 'ADV')),
#  (('le', 'NOUN'), ('le', 'DET')),
#  (('back', 'PRT'), ('back', 'ADV')),
#  (('care', 'VERB'), ('care', 'NOUN')),
#  (('care', 'VERB'), ('care', 'NOUN')),
#  (('clear', 'ADJ'), ('clear', 'VERB')),
#  (('fuel', 'NOUN'), ('fuel', 'VERB')),
#  (('84-year-old', 'NOUN'), ('84-year-old', 'ADJ')),
#  (('amazingly', 'NOUN'), ('amazingly', 'ADV')),
#  (('*T*-178', 'NOUN'), ('*T*-178', 'X')),
#  (('*-154', 'NOUN'), ('*-154', 'X')),
#  (('individual', 'ADJ'), ('individual', 'NOUN')),
#  (('intelligent', 'NOUN'), ('intelligent', 'ADJ')),
#  (('insane', 'NOUN'), ('insane', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('tailor-made', 'NOUN'), ('tailor-made', 'ADJ')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('purhasing', 'VERB'), ('purhasing', 'NOUN')),
#  (('report', 'VERB'), ('report', 'NOUN')),
#  (('movies', 'VERB'), ('movies', 'NOUN')),
#  (('marvelously', 'NOUN'), ('marvelously', 'ADV')),
#  (('loose', 'NOUN'), ('loose', 'ADJ')),
#  (('work', 'VERB'), ('work', 'NOUN')),
#  (('force', 'VERB'), ('force', 'NOUN')),
#  (('refer', 'NOUN'), ('refer', 'VERB')),
#  (('clouding', 'VERB'), ('clouding', 'NOUN')),
#  (('*-107', 'NOUN'), ('*-107', 'X')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('solemn', 'NOUN'), ('solemn', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-226', 'NOUN'), ('*T*-226', 'X')),
#  (('intricate', 'NOUN'), ('intricate', 'ADJ')),
#  (('faultlessly', 'NOUN'), ('faultlessly', 'ADV')),
#  (('properties', 'VERB'), ('properties', 'NOUN')),
#  (('Indexing', 'VERB'), ('Indexing', 'NOUN')),
#  (('panic', 'NOUN'), ('panic', 'VERB')),
#  (('so', 'ADV'), ('so', 'ADP')),
#  (('assistant', 'NOUN'), ('assistant', 'ADJ')),
#  (('following', 'NOUN'), ('following', 'VERB')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('shown', 'NOUN'), ('shown', 'VERB')),
#  (('finest', 'NOUN'), ('finest', 'ADJ')),
#  (('defeats', 'NOUN'), ('defeats', 'VERB')),
#  (('inkling', 'VERB'), ('inkling', 'NOUN')),
#  (('underprivileged', 'VERB'), ('underprivileged', 'ADJ')),
#  (('*T*-96', 'NOUN'), ('*T*-96', 'X')),
#  (('much', 'ADJ'), ('much', 'ADV')),
#  (('savvier', 'NOUN'), ('savvier', 'ADJ')),
#  (('much', 'ADV'), ('much', 'ADJ')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('as', 'ADP'), ('as', 'ADV')),
#  (('Above', 'NOUN'), ('Above', 'ADP')),
#  (('confused', 'ADJ'), ('confused', 'VERB')),
#  (('around', 'ADP'), ('around', 'PRT')),
#  (('blinks', 'NOUN'), ('blinks', 'VERB')),
#  (('bar', 'NOUN'), ('bar', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('abortion-related', 'VERB'), ('abortion-related', 'ADJ')),
#  (("'s", 'PRT'), ("'s", 'VERB')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('further', 'ADJ'), ('further', 'ADV')),
#  (('load', 'NOUN'), ('load', 'VERB')),
#  (('up', 'ADV'), ('up', 'PRT')),
#  (('improbable', 'NOUN'), ('improbable', 'ADJ')),
#  (('high-rise', 'NOUN'), ('high-rise', 'ADJ')),
#  (('help', 'VERB'), ('help', 'NOUN')),
#  (('plastic', 'ADJ'), ('plastic', 'NOUN')),
#  (('non-biodegradable', 'NOUN'), ('non-biodegradable', 'ADJ')),
#  (('over', 'ADP'), ('over', 'PRT')),
#  (('seventh', 'NOUN'), ('seventh', 'ADJ')),
#  (("'82", 'NOUN'), ("'82", 'NUM')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('closer', 'ADV'), ('closer', 'ADJ')),
#  (('unwilling', 'VERB'), ('unwilling', 'ADJ')),
#  (('index-fund', 'NOUN'), ('index-fund', 'ADJ')),
#  (('more', 'ADV'), ('more', 'ADJ')),
#  (('own', 'ADJ'), ('own', 'VERB')),
#  (('charge', 'NOUN'), ('charge', 'VERB')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('matters', 'NOUN'), ('matters', 'VERB')),
#  (('fine', 'NOUN'), ('fine', 'ADV')),
#  (('chief', 'NOUN'), ('chief', 'ADJ')),
#  (('*-152', 'NOUN'), ('*-152', 'X')),
#  (('wealthy', 'NOUN'), ('wealthy', 'ADJ')),
#  (('well-connected', 'VERB'), ('well-connected', 'ADJ')),
#  (('financing', 'VERB'), ('financing', 'NOUN')),
#  (('American', 'ADJ'), ('American', 'NOUN')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('cavernous', 'NOUN'), ('cavernous', 'ADJ')),
#  (('money-losing', 'VERB'), ('money-losing', 'ADJ')),
#  (('benefits', 'NOUN'), ('benefits', 'VERB')),
#  (('U.S.', 'NOUN'), ('U.S.', 'ADJ')),
#  (('close', 'VERB'), ('close', 'NOUN')),
#  (('appeal', 'NOUN'), ('appeal', 'VERB')),
#  (('burn', 'NOUN'), ('burn', 'VERB')),
#  (('cleaner-burning', 'VERB'), ('cleaner-burning', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('select', 'NOUN'), ('select', 'VERB')),
#  (('net', 'ADJ'), ('net', 'NOUN')),
#  (('unrestricted', 'VERB'), ('unrestricted', 'ADJ')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*-165', 'NOUN'), ('*-165', 'X')),
#  (('firm', 'NOUN'), ('firm', 'ADJ')),
#  (('opening', 'VERB'), ('opening', 'NOUN')),
#  (('less', 'ADV'), ('less', 'ADJ')),
#  (('higher', 'ADJ'), ('higher', 'ADV')),
#  (('trading', 'NOUN'), ('trading', 'VERB')),
#  (('1980s', 'NUM'), ('1980s', 'NOUN')),
#  (('yellow', 'NOUN'), ('yellow', 'ADJ')),
#  (('record', 'NOUN'), ('record', 'ADJ')),
#  (('Four', 'NOUN'), ('Four', 'NUM')),
#  (('half', 'DET'), ('half', 'NOUN')),
#  (('27-year', 'NOUN'), ('27-year', 'ADJ')),
#  (('information-services', 'VERB'), ('information-services', 'NOUN')),
#  (('Southeast', 'NOUN'), ('Southeast', 'ADJ')),
#  (('uses', 'VERB'), ('uses', 'NOUN')),
#  (('cancer-causing', 'VERB'), ('cancer-causing', 'ADJ')),
#  (('post', 'VERB'), ('post', 'NOUN')),
#  (('little', 'ADJ'), ('little', 'ADV')),
#  (('more', 'ADJ'), ('more', 'ADV')),
#  (('what', 'PRON'), ('what', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('*T*-117', 'NOUN'), ('*T*-117', 'X')),
#  (('uptick', 'NOUN'), ('uptick', 'VERB')),
#  (('head', 'NOUN'), ('head', 'ADJ')),
#  (('comments', 'NOUN'), ('comments', 'VERB')),
#  (('increases', 'NOUN'), ('increases', 'VERB')),
#  (('63-year-old', 'NOUN'), ('63-year-old', 'ADJ')),
#  (('English', 'ADJ'), ('English', 'NOUN')),
#  (('CoreStates', 'VERB'), ('CoreStates', 'NOUN')),
#  (('account', 'VERB'), ('account', 'NOUN')),
#  (('there', 'DET'), ('there', 'ADV')),
#  (('what', 'PRON'), ('what', 'DET')),
#  (('open', 'VERB'), ('open', 'ADJ')),
#  (('drink', 'VERB'), ('drink', 'NOUN')),
#  (('up', 'ADV'), ('up', 'ADP')),
#  (('cardiovascular', 'NOUN'), ('cardiovascular', 'ADJ')),
#  (('infectious', 'NOUN'), ('infectious', 'ADJ')),
#  (('*T*-91', 'NOUN'), ('*T*-91', 'X')),
#  (('guarantee', 'VERB'), ('guarantee', 'NOUN')),
#  (('operating', 'NOUN'), ('operating', 'VERB')),
#  (('that', 'ADP'), ('that', 'DET')),
#  (('half', 'DET'), ('half', 'NOUN')),
#  (('espouse', 'NOUN'), ('espouse', 'VERB')),
#  (('about', 'ADP'), ('about', 'ADV')),
#  (('one-third', 'NOUN'), ('one-third', 'ADJ')),
#  (('finance', 'VERB'), ('finance', 'NOUN')),
#  (('59-year-old', 'NOUN'), ('59-year-old', 'ADJ')),
#  (('heebie-jeebies', 'VERB'), ('heebie-jeebies', 'NOUN')),
#  (('much', 'ADV'), ('much', 'ADJ')),
#  (('point', 'VERB'), ('point', 'NOUN')),
#  (('audit', 'VERB'), ('audit', 'NOUN')),
#  (('stand', 'VERB'), ('stand', 'NOUN')),
#  (('display', 'NOUN'), ('display', 'VERB')),
#  (('underline', 'NOUN'), ('underline', 'VERB')),
#  (('publishing', 'VERB'), ('publishing', 'NOUN')),
#  (('all', 'DET'), ('all', 'ADV')),
#  (('following', 'VERB'), ('following', 'NOUN')),
#  (('round-trip', 'NOUN'), ('round-trip', 'ADJ')),
#  (('240-page', 'NOUN'), ('240-page', 'ADJ')),
#  (('Next', 'NOUN'), ('Next', 'ADJ')),
#  (('launch', 'VERB'), ('launch', 'NOUN')),
#  (('capped', 'ADJ'), ('capped', 'VERB')),
#  (('Philippine', 'NOUN'), ('Philippine', 'ADJ')),
#  (('the', 'DET'), ('the', 'NOUN')),
#  (('Spending', 'VERB'), ('Spending', 'NOUN')),
#  (('nonresidential', 'NOUN'), ('nonresidential', 'ADJ')),
#  (('off', 'PRT'), ('off', 'ADJ')),
#  (('awaits', 'NOUN'), ('awaits', 'VERB')),
#  (('point', 'NOUN'), ('point', 'VERB')),
#  (('B-1B', 'ADJ'), ('B-1B', 'NOUN')),
#  (('out', 'PRT'), ('out', 'ADP')),
#  (('half', 'NOUN'), ('half', 'DET')),
#  (('earlier', 'ADV'), ('earlier', 'ADJ')),
#  (('next', 'ADP'), ('next', 'ADJ')),
#  (('Soviet', 'ADJ'), ('Soviet', 'NOUN')),
#  (('off', 'PRT'), ('off', 'ADP')),
#  (('broadly', 'NOUN'), ('broadly', 'ADV')),
#  (('emasculate', 'NOUN'), ('emasculate', 'VERB')),
#  (('swallow', 'NOUN'), ('swallow', 'VERB')),
#  (('contrary', 'NOUN'), ('contrary', 'ADJ')),
#  (('the', 'DET'), ('the', 'NUM'))]

# %% [markdown]
# ### Compare the tagging accuracies of the modifications with the vanilla Viterbi algorithm

# %%
#Vanilla Viterbi accuracy
print("Vanilla Viterb accuracy --------> ",accuracy)

#Lexicom based modification accuracy
print("Lexicon based approach with Viterbi accuracy--------> ",accuracy_mod1)

#Rule based modification accuracy
print("Rule based approach with Viterbi accuracy--------> ",accuracy_mod2)
# Out:
# Vanilla Viterb accuracy -------->  0.91030251745293
# Lexicon based approach with Viterbi accuracy-------->  0.9348423947535435
# Rule based approach with Viterbi accuracy-------->  0.946689232071081

# %% [markdown]
# ## 5. List down words which were incorrectly tagged by Vanilla Viterbi and got corrected with Modification 1 & 2 (Lexicon and Rule based)

# %%
# Words incorrectly tagged by Vanilla Viterbi

incorrect_tag_words_vanilla = [item[0][0].lower() for item in incorrect_tagged_cases ]
len(set(incorrect_tag_words_vanilla))
# Out:
# 372

# %%
# Words incorrectly tagged by Lexicon with Viterbi

incorrect_tag_words_mod1 = [item[0][0].lower() for item in incorrect_tagged_cases_mod1 ]
len(set(incorrect_tag_words_mod1))
# Out:
# 259

# %%
# Words incorrectly tagged by Rule based with Viterbi

incorrect_tag_words_mod2 = [item[0][0].lower() for item in incorrect_tagged_cases_mod2 ]
len(set(incorrect_tag_words_mod2))
# Out:
# 203

# %%
# Words Correctly tagged by Lexicon tagger which are wrongly tagged by Vanilla Viterbi

incorrect_tag_words_vanilla_tmp = set([x.lower() for x in incorrect_tag_words_vanilla])
incorrect_tag_words_mod1_tmp = set([x.lower() for x in incorrect_tag_words_mod1])
vanilla_mod1_correctly_tagged_tmp = [item for item in incorrect_tag_words_mod1_tmp
                                 if item not in incorrect_tag_words_vanilla_tmp]
print(list(set(vanilla_mod1_correctly_tagged_tmp)))
# Out:
# ['51.6', '94.8', '221.4', '1997', '89.7', '126,000', '879', '8.75', '960', '550,000', '14.75', '12.52', '143.93', "'82", '115', '143.08', '472', '11.95', '77.6', '88.32', '609', '306', '13.90', '692', '858,000', 'four', '99.1', '141.9', '150.00', '3.19', '149.9', '618.1', 'five']

# %%
# Words Correctly tagged by Rule based tagger which are wrongly tagged by lexicon tagger

incorrect_tag_words_mod1_tmp = set([x.lower() for x in incorrect_tag_words_mod1])
incorrect_tag_words_mod2_tmp = set([x.lower() for x in incorrect_tag_words_mod2])
mod1_mod2_correctly_tagged = [item for item in incorrect_tag_words_mod1_tmp if item not in incorrect_tag_words_mod2_tmp]
print(list(set(mod1_mod2_correctly_tagged)))
# Out:
# ['51.6', 'broadened', 'delayed', '94.8', 'curbed', '221.4', 'burned', '1997', 'sagged', 'removing', 'shopped', '89.7', 'owning', '126,000', '879', '8.75', 'flirted', 'stemmed', '960', '550,000', 'descending', 'outlawing', 'overvalued', 'tempted', '14.75', 'disapproved', 'dreamed', '12.52', 'faded', 'reclaimed', 'illustrates', '143.93', 'safeguarding', 'diagnosed', '115', 'deteriorating', 'outlawed', '143.08', '472', '11.95', '77.6', 'headed', 'wrestling', '88.32', 'clamped', 'leveraging', '609', 'pushes', '306', 'crying', '13.90', '692', '858,000', 'filled', 'ignored', 'soaring', '99.1', 'cultivated', '150.00', '141.9', 'inserted', 'argues', '3.19', '149.9', '618.1', 'maturing', 'construed']

# %% [markdown]
# ### 6. Tagging the Sample test file

# %%
# Read File
file1 = open("Test_sentences.txt","r+")

sample_test_data= file1.read()
sample_test_data = sample_test_data.replace("\n"," ")
sample_test_data = sample_test_data.lower()
words = word_tokenize(sample_test_data)

# %%
# Tagging with Vanilla Viterbi

tagged_seq = Viterbi(words)

# %%
# Tagging with Lexicon based tagger

tagged_seq_1 = Viterbi_mod1(words)
tagged_seq_1
# Out:
# [('android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('google', 'NOUN'),
#  ('.', '.'),
#  ('android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('os', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'NOUN'),
#  ('since', 'ADP'),
#  ('2011', 'NOUN'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013.', 'NOUN'),
#  ('google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NOUN'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'NOUN'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NOUN'),
#  ('.', '.'),
#  ('before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('donald', 'NOUN'),
#  ('trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'NOUN'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('2018', 'NOUN'),
#  ('fifa', 'NOUN'),
#  ('world', 'NOUN'),
#  ('cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('fifa', 'NOUN'),
#  ('world', 'NOUN'),
#  ('cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'NOUN'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('this', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('world', 'NOUN'),
#  ('cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('eastern', 'NOUN'),
#  ('europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('europe', 'NOUN'),
#  ('.', '.'),
#  ('show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('atlanta', 'NOUN'),
#  ('i', 'NOUN'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'NOUN'),
#  ('in', 'ADP'),
#  ('san', 'NOUN'),
#  ('francisco', 'NOUN'),
#  ('.', '.'),
#  ('nasa', 'NOUN'),
#  ('invited', 'NOUN'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('icesat-2', 'NOUN'),
#  ('satellite', 'NOUN'),
#  ('.', '.')]

# %%
# Tagging with Rule based Tagger

tagged_seq_2 = Viterbi_mod2(words)
tagged_seq_2
# Out:
# [('android', 'NOUN'),
#  ('is', 'VERB'),
#  ('a', 'DET'),
#  ('mobile', 'ADJ'),
#  ('operating', 'NOUN'),
#  ('system', 'NOUN'),
#  ('developed', 'VERB'),
#  ('by', 'ADP'),
#  ('google', 'NOUN'),
#  ('.', '.'),
#  ('android', 'NOUN'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('the', 'DET'),
#  ('best-selling', 'ADJ'),
#  ('os', 'NOUN'),
#  ('worldwide', 'NOUN'),
#  ('on', 'ADP'),
#  ('smartphones', 'VERB'),
#  ('since', 'ADP'),
#  ('2011', 'NUM'),
#  ('and', 'CONJ'),
#  ('on', 'ADP'),
#  ('tablets', 'NOUN'),
#  ('since', 'ADP'),
#  ('2013.', 'NOUN'),
#  ('google', 'NOUN'),
#  ('and', 'CONJ'),
#  ('twitter', 'NOUN'),
#  ('made', 'VERB'),
#  ('a', 'DET'),
#  ('deal', 'NOUN'),
#  ('in', 'ADP'),
#  ('2015', 'NUM'),
#  ('that', 'ADP'),
#  ('gave', 'VERB'),
#  ('google', 'NOUN'),
#  ('access', 'NOUN'),
#  ('to', 'PRT'),
#  ('twitter', 'NOUN'),
#  ("'s", 'PRT'),
#  ('firehose', 'NOUN'),
#  ('.', '.'),
#  ('twitter', 'NOUN'),
#  ('is', 'VERB'),
#  ('an', 'DET'),
#  ('online', 'NOUN'),
#  ('news', 'NOUN'),
#  ('and', 'CONJ'),
#  ('social', 'ADJ'),
#  ('networking', 'NOUN'),
#  ('service', 'NOUN'),
#  ('on', 'ADP'),
#  ('which', 'DET'),
#  ('users', 'NOUN'),
#  ('post', 'NOUN'),
#  ('and', 'CONJ'),
#  ('interact', 'NOUN'),
#  ('with', 'ADP'),
#  ('messages', 'VERB'),
#  ('known', 'VERB'),
#  ('as', 'ADP'),
#  ('tweets', 'NOUN'),
#  ('.', '.'),
#  ('before', 'ADP'),
#  ('entering', 'VERB'),
#  ('politics', 'NOUN'),
#  (',', '.'),
#  ('donald', 'NOUN'),
#  ('trump', 'NOUN'),
#  ('was', 'VERB'),
#  ('a', 'DET'),
#  ('domineering', 'VERB'),
#  ('businessman', 'NOUN'),
#  ('and', 'CONJ'),
#  ('a', 'DET'),
#  ('television', 'NOUN'),
#  ('personality', 'NOUN'),
#  ('.', '.'),
#  ('the', 'DET'),
#  ('2018', 'NUM'),
#  ('fifa', 'NOUN'),
#  ('world', 'NOUN'),
#  ('cup', 'NOUN'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('21st', 'NOUN'),
#  ('fifa', 'NOUN'),
#  ('world', 'NOUN'),
#  ('cup', 'NOUN'),
#  (',', '.'),
#  ('an', 'DET'),
#  ('international', 'ADJ'),
#  ('football', 'NOUN'),
#  ('tournament', 'NOUN'),
#  ('contested', 'VERB'),
#  ('once', 'ADV'),
#  ('every', 'DET'),
#  ('four', 'NUM'),
#  ('years', 'NOUN'),
#  ('.', '.'),
#  ('this', 'DET'),
#  ('is', 'VERB'),
#  ('the', 'DET'),
#  ('first', 'ADJ'),
#  ('world', 'NOUN'),
#  ('cup', 'NOUN'),
#  ('to', 'PRT'),
#  ('be', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('eastern', 'NOUN'),
#  ('europe', 'NOUN'),
#  ('and', 'CONJ'),
#  ('the', 'DET'),
#  ('11th', 'ADJ'),
#  ('time', 'NOUN'),
#  ('that', 'ADP'),
#  ('it', 'PRON'),
#  ('has', 'VERB'),
#  ('been', 'VERB'),
#  ('held', 'VERB'),
#  ('in', 'ADP'),
#  ('europe', 'NOUN'),
#  ('.', '.'),
#  ('show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('cheapest', 'ADJ'),
#  ('round', 'NOUN'),
#  ('trips', 'NOUN'),
#  ('from', 'ADP'),
#  ('dallas', 'NOUN'),
#  ('to', 'PRT'),
#  ('atlanta', 'NOUN'),
#  ('i', 'NOUN'),
#  ('would', 'VERB'),
#  ('like', 'ADP'),
#  ('to', 'PRT'),
#  ('see', 'VERB'),
#  ('flights', 'NOUN'),
#  ('from', 'ADP'),
#  ('denver', 'NOUN'),
#  ('to', 'PRT'),
#  ('philadelphia', 'NOUN'),
#  ('.', '.'),
#  ('show', 'NOUN'),
#  ('me', 'PRON'),
#  ('the', 'DET'),
#  ('price', 'NOUN'),
#  ('of', 'ADP'),
#  ('the', 'DET'),
#  ('flights', 'NOUN'),
#  ('leaving', 'VERB'),
#  ('atlanta', 'NOUN'),
#  ('at', 'ADP'),
#  ('about', 'ADP'),
#  ('3', 'NUM'),
#  ('in', 'ADP'),
#  ('the', 'DET'),
#  ('afternoon', 'NOUN'),
#  ('and', 'CONJ'),
#  ('arriving', 'VERB'),
#  ('in', 'ADP'),
#  ('san', 'NOUN'),
#  ('francisco', 'NOUN'),
#  ('.', '.'),
#  ('nasa', 'NOUN'),
#  ('invited', 'VERB'),
#  ('social', 'ADJ'),
#  ('media', 'NOUN'),
#  ('users', 'NOUN'),
#  ('to', 'PRT'),
#  ('experience', 'NOUN'),
#  ('the', 'DET'),
#  ('launch', 'NOUN'),
#  ('of', 'ADP'),
#  ('icesat-2', 'NOUN'),
#  ('satellite', 'NOUN'),
#  ('.', '.')]

# %%
# Tagging of words in Lexicon tagger in comparison with Vanilla Viterbi
unkown_set_tagging_vanilla_mod1 = [ (x[0],"Current-tag: " + x[1], "Previous-tag: "+ y[1]) for x in tagged_seq_1 for y in tagged_seq if x[1] != y[1]  and x[0] == y[0]]
print(len(set(unkown_set_tagging_vanilla_mod1)))

# Tagging of words in Rule based tagger in comparison with Vanilla Viterbi
unkown_set_tagging_vanilla_mod2 = [ (x[0],"Current-tag: " + x[1],"Previous-tag: "+ y[1]) for x in tagged_seq_2 for y in tagged_seq if x[1] != y[1]  and x[0] == y[0]]
print(len(set(unkown_set_tagging_vanilla_mod2)))

# Tagging of words in Rule based tagger in comparison with Lexicon tagger
unkown_set_tagging_mod1_mod2 = [ (x[0],"Current-tag: " + x[1],"Previous-tag: "+ y[1]) for x in tagged_seq_2 for y in tagged_seq_1 if x[1] != y[1]  and x[0] == y[0]]
print(len(set(unkown_set_tagging_mod1_mod2)))
# Out:
# 39
# 36
# 9

# %%
print("===============Tagging of lexicon tagger VS Viterbi Vanilla============")
print()
print(list(set(unkown_set_tagging_vanilla_mod1)))
print()
print("--------Tag Correction Case 1-----------------------------------")
print(list(set(unkown_set_tagging_vanilla_mod1))[0])
print("----------------------------------------------------------------")
print()
print("--------Tag Correction Case 2-----------------------------------")
print(list(set(unkown_set_tagging_vanilla_mod1))[1])
print("----------------------------------------------------------------")
print()
print("--------Tag Correction Case 3-----------------------------------")
print(list(set(unkown_set_tagging_vanilla_mod1))[5])
print("----------------------------------------------------------------")
print()
print("===================================================================================")
# Out:
# ===============Tagging of lexicon tagger VS Viterbi Vanilla============
#
# [('tournament', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('francisco', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('2015', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('2018', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('invited', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('smartphones', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('domineering', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('denver', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('2011', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('google', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('contested', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('android', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('interact', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('arriving', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('donald', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('2013.', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('eastern', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('philadelphia', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('dallas', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('cup', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('messages', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('icesat-2', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('satellite', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('trump', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('europe', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('os', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('firehose', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('worldwide', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('trips', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('personality', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('21st', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('fifa', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('twitter', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('atlanta', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('i', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('tweets', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('san', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('nasa', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('online', 'Current-tag: NOUN', 'Previous-tag: NUM')]
#
# --------Tag Correction Case 1-----------------------------------
# ('tournament', 'Current-tag: NOUN', 'Previous-tag: NUM')
# ----------------------------------------------------------------
#
# --------Tag Correction Case 2-----------------------------------
# ('francisco', 'Current-tag: NOUN', 'Previous-tag: NUM')
# ----------------------------------------------------------------
#
# --------Tag Correction Case 3-----------------------------------
# ('smartphones', 'Current-tag: NOUN', 'Previous-tag: NUM')
# ----------------------------------------------------------------
#
# ===================================================================================

# %%
print("===============Tagging of Rule based tagger VS Viterbi Vanilla============")
print()
print(list(set(unkown_set_tagging_vanilla_mod2)))
print()
print("--------Tag Correction Case 1------------------------------------")
print(list(set(unkown_set_tagging_vanilla_mod2))[13])
print("-----------------------------------------------------------------")
print()
print("--------Tag Correction Case 2------------------------------------")
print(list(set(unkown_set_tagging_vanilla_mod2))[10])
print("-----------------------------------------------------------------")
print()
print("--------Tag Correction Case 3------------------------------------")
print(list(set(unkown_set_tagging_vanilla_mod2))[12])
print("-----------------------------------------------------------------")
print()
print("===================================================================================")
# Out:
# ===============Tagging of Rule based tagger VS Viterbi Vanilla============
#
# [('tournament', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('francisco', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('domineering', 'Current-tag: VERB', 'Previous-tag: NUM'), ('messages', 'Current-tag: VERB', 'Previous-tag: NUM'), ('denver', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('google', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('android', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('interact', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('donald', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('2013.', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('invited', 'Current-tag: VERB', 'Previous-tag: NUM'), ('eastern', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('philadelphia', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('dallas', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('cup', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('icesat-2', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('satellite', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('trump', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('europe', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('os', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('firehose', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('worldwide', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('smartphones', 'Current-tag: VERB', 'Previous-tag: NUM'), ('trips', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('personality', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('21st', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('fifa', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('twitter', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('atlanta', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('i', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('tweets', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('contested', 'Current-tag: VERB', 'Previous-tag: NUM'), ('san', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('online', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('nasa', 'Current-tag: NOUN', 'Previous-tag: NUM'), ('arriving', 'Current-tag: VERB', 'Previous-tag: NUM')]
#
# --------Tag Correction Case 1------------------------------------
# ('dallas', 'Current-tag: NOUN', 'Previous-tag: NUM')
# -----------------------------------------------------------------
#
# --------Tag Correction Case 2------------------------------------
# ('invited', 'Current-tag: VERB', 'Previous-tag: NUM')
# -----------------------------------------------------------------
#
# --------Tag Correction Case 3------------------------------------
# ('philadelphia', 'Current-tag: NOUN', 'Previous-tag: NUM')
# -----------------------------------------------------------------
#
# ===================================================================================

# %%
print("===============Tagging of Rule based tagger VS Lexicon Tagger============")
print()
print(list(set(unkown_set_tagging_mod1_mod2)))
print()
print("--------Tag Correction Case 1------------------------------------")
print(list(set(unkown_set_tagging_mod1_mod2))[0])
print("-----------------------------------------------------------------")
print()
print("--------Tag Correction Case 2------------------------------------")
print(list(set(unkown_set_tagging_mod1_mod2))[1])
print("-----------------------------------------------------------------")
print()
print("--------Tag Correction Case 3------------------------------------")
print(list(set(unkown_set_tagging_mod1_mod2))[3])
print("-----------------------------------------------------------------")
print()
print("===================================================================================")
# Out:
# ===============Tagging of Rule based tagger VS Lexicon Tagger============
#
# [('2018', 'Current-tag: NUM', 'Previous-tag: NOUN'), ('2011', 'Current-tag: NUM', 'Previous-tag: NOUN'), ('arriving', 'Current-tag: VERB', 'Previous-tag: NOUN'), ('contested', 'Current-tag: VERB', 'Previous-tag: NOUN'), ('domineering', 'Current-tag: VERB', 'Previous-tag: NOUN'), ('2015', 'Current-tag: NUM', 'Previous-tag: NOUN'), ('invited', 'Current-tag: VERB', 'Previous-tag: NOUN'), ('smartphones', 'Current-tag: VERB', 'Previous-tag: NOUN'), ('messages', 'Current-tag: VERB', 'Previous-tag: NOUN')]
#
# --------Tag Correction Case 1------------------------------------
# ('2018', 'Current-tag: NUM', 'Previous-tag: NOUN')
# -----------------------------------------------------------------
#
# --------Tag Correction Case 2------------------------------------
# ('2011', 'Current-tag: NUM', 'Previous-tag: NOUN')
# -----------------------------------------------------------------
#
# --------Tag Correction Case 3------------------------------------
# ('contested', 'Current-tag: VERB', 'Previous-tag: NOUN')
# -----------------------------------------------------------------
#
# ===================================================================================
